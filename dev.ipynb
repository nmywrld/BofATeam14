# %% [markdown]
# impo

# %%
import csv
import heapq
from orderNode import orderNode
from buyOrderNode import buyOrderNode
from sellOrderNode import sellOrderNode

# %%
def csv_to_ArrayDict(filename):
    with open(filename, mode='r') as infile:
        reader = csv.DictReader(infile)
        data = [row for row in reader]
    return data

def csv_to_dict(filename):
    with open(filename, mode='r') as infile:
        reader = csv.DictReader(infile)
        data = {row[next(iter(reader.fieldnames))]: {key: value for key, value in row.items() if key != next(iter(reader.fieldnames))} for row in reader}
    return data

def time_string_to_int(time_string): 
    #input "9:02:43" output: time 
    split_arr = time_string.split(":") 
    final_time = 0 
    final_time += int(split_arr[0]) * 60 * 60 
    final_time += int(split_arr[1]) * 60 
    final_time += int(split_arr[2]) 
    return final_time

# %%
client_data = csv_to_dict('./test-set/input_clients.csv')
print(client_data)
# Out:
# {'CLIENT_100': {'Currencies': 'SGD,JPY', 'PositionCheck': 'Y', 'Rating': '1'}, 'CLIENT_101': {'Currencies': 'USD,JPY,SGD', 'PositionCheck': 'N', 'Rating': '10'}, 'CLIENT_102': {'Currencies': 'SGD', 'PositionCheck': 'Y', 'Rating': '3'}, 'CLIENT_103': {'Currencies': 'SGD,USD,JPY', 'PositionCheck': 'N', 'Rating': '8'}, 'CLIENT_104': {'Currencies': 'SGD,JPY,USD', 'PositionCheck': 'Y', 'Rating': '9'}, 'CLIENT_105': {'Currencies': 'JPY,USD,SGD', 'PositionCheck': 'Y', 'Rating': '3'}, 'CLIENT_106': {'Currencies': 'JPY', 'PositionCheck': 'Y', 'Rating': '4'}, 'CLIENT_107': {'Currencies': 'JPY', 'PositionCheck': 'Y', 'Rating': '7'}, 'CLIENT_108': {'Currencies': 'SGD,USD,JPY', 'PositionCheck': 'Y', 'Rating': '5'}, 'CLIENT_109': {'Currencies': 'USD,SGD,JPY', 'PositionCheck': 'Y', 'Rating': '3'}, 'CLIENT_110': {'Currencies': 'SGD,JPY', 'PositionCheck': 'Y', 'Rating': '5'}, 'CLIENT_111': {'Currencies': 'SGD,JPY,USD', 'PositionCheck': 'Y', 'Rating': '6'}, 'CLIENT_112': {'Currencies': 'JPY,USD,SGD', 'PositionCheck': 'Y', 'Rating': '4'}, 'CLIENT_113': {'Currencies': 'SGD', 'PositionCheck': 'Y', 'Rating': '4'}, 'CLIENT_114': {'Currencies': 'USD,JPY', 'PositionCheck': 'Y', 'Rating': '2'}}

# %%
inst_data = csv_to_dict('./test-set/input_instruments.csv')
print(inst_data)
# Out:
# {'INST_000': {'Currency': 'SGD', 'LotSize': '1000'}, 'INST_001': {'Currency': 'USD', 'LotSize': '100'}, 'INST_002': {'Currency': 'JPY', 'LotSize': '1'}, 'INST_003': {'Currency': 'SGD', 'LotSize': '1'}, 'INST_004': {'Currency': 'USD', 'LotSize': '100'}, 'INST_005': {'Currency': 'JPY', 'LotSize': '1000'}, 'INST_006': {'Currency': 'SGD', 'LotSize': '1'}, 'INST_007': {'Currency': 'USD', 'LotSize': '1'}, 'INST_008': {'Currency': 'JPY', 'LotSize': '1000'}, 'INST_009': {'Currency': 'SGD', 'LotSize': '1000'}}

# %%
order_data = csv_to_ArrayDict('./test-set/input_orders.csv')
print(order_data)
# Out:
# [{'Time': '09:00:00', 'OrderID': 'ORDER_10', 'Instrument': 'INST_000', 'Quantity': '17500.0', 'Client': 'CLIENT_107', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_1430', 'Instrument': 'INST_000', 'Quantity': '3000', 'Client': 'CLIENT_111', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_1860', 'Instrument': 'INST_000', 'Quantity': '46000', 'Client': 'CLIENT_113', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_20', 'Instrument': 'INST_001', 'Quantity': '4350.0', 'Client': 'CLIENT_106', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_2430', 'Instrument': 'INST_001', 'Quantity': '8700', 'Client': 'CLIENT_103', 'Price': 'Market', 'Side': 'Buy'}, {'Time': '09:00:00', 'OrderID': 'ORDER_2860', 'Instrument': 'INST_001', 'Quantity': '2700', 'Client': 'CLIENT_101', 'Price': 'Market', 'Side': 'Buy'}, {'Time': '09:00:00', 'OrderID': 'ORDER_30', 'Instrument': 'INST_002', 'Quantity': '30.5', 'Client': 'CLIENT_102', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_3430', 'Instrument': 'INST_002', 'Quantity': '89', 'Client': 'CLIENT_105', 'Price': 'Market', 'Side': 'Buy'}, {'Time': '09:00:00', 'OrderID': 'ORDER_3860', 'Instrument': 'INST_002', 'Quantity': '76', 'Client': 'CLIENT_107', 'Price': 'Market', 'Side': 'Buy'}, {'Time': '09:00:00', 'OrderID': 'ORDER_40', 'Instrument': 'INST_003', 'Quantity': '77.5', 'Client': 'CLIENT_106', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_4430', 'Instrument': 'INST_003', 'Quantity': '100', 'Client': 'CLIENT_109', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_4860', 'Instrument': 'INST_003', 'Quantity': '87', 'Client': 'CLIENT_100', 'Price': 'Market', 'Side': 'Buy'}, {'Time': '09:00:00', 'OrderID': 'ORDER_50', 'Instrument': 'INST_004', 'Quantity': '2850.0', 'Client': 'CLIENT_102', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_5430', 'Instrument': 'INST_004', 'Quantity': '1500', 'Client': 'CLIENT_114', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_5860', 'Instrument': 'INST_004', 'Quantity': '800', 'Client': 'CLIENT_109', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_60', 'Instrument': 'INST_005', 'Quantity': '96500.0', 'Client': 'CLIENT_113', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_6430', 'Instrument': 'INST_005', 'Quantity': '9000', 'Client': 'CLIENT_110', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_6860', 'Instrument': 'INST_005', 'Quantity': '71000', 'Client': 'CLIENT_111', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_70', 'Instrument': 'INST_006', 'Quantity': '84.5', 'Client': 'CLIENT_114', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_7430', 'Instrument': 'INST_006', 'Quantity': '34', 'Client': 'CLIENT_111', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_7860', 'Instrument': 'INST_006', 'Quantity': '11', 'Client': 'CLIENT_113', 'Price': 'Market', 'Side': 'Buy'}, {'Time': '09:00:00', 'OrderID': 'ORDER_80', 'Instrument': 'INST_007', 'Quantity': '42.5', 'Client': 'CLIENT_102', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_8430', 'Instrument': 'INST_007', 'Quantity': '21', 'Client': 'CLIENT_114', 'Price': 'Market', 'Side': 'Buy'}, {'Time': '09:00:00', 'OrderID': 'ORDER_8860', 'Instrument': 'INST_007', 'Quantity': '20', 'Client': 'CLIENT_103', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_90', 'Instrument': 'INST_008', 'Quantity': '82500.0', 'Client': 'CLIENT_102', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_9430', 'Instrument': 'INST_008', 'Quantity': '1000', 'Client': 'CLIENT_114', 'Price': 'Market', 'Side': 'Sell'}, {'Time': '09:00:00', 'OrderID': 'ORDER_9860', 'Instrument': 'INST_008', ' ...

# %%
# while True:
#     order = heapq.heappop(instrument_dict['INST_001']['buy_heap'])
#     print(order.time, order.order_id, order.quantity, order.client_id, order.price, order.buy_or_sell, order.client_rating, order.client_position_check)
#     print()

# %%
# node = orderNode(time, order_id, instrument, quantity, client_id, price, buy_or_sell, client_rating, client_position_check)

# loop through order_data and create orderNodes and put it inside a variable called orderBook

instrument_dict= {}

buyHeap = []
sellHeap = []
buyHeapMarket = []
sellHeapMarket = []

heapq.heapify(buyHeap)
heapq.heapify(sellHeap)
heapq.heapify(buyHeapMarket)
heapq.heapify(sellHeapMarket)

for order in order_data: 
     
    if order['Instrument'] not in instrument_dict: 
        instrument_dict[order['Instrument']] = {'buy_heap' :[], 'sell_heap':[], 'sell_market_heap':[], 'buy_market_heap':[]} 
        buy_heap = instrument_dict[order['Instrument']]['buy_heap'] 
        buy_market_heap = instrument_dict[order['Instrument']]['buy_market_heap'] 
        sell_heap = instrument_dict[order['Instrument']]['sell_heap'] 
        sell_market_heap = instrument_dict[order['Instrument']]['sell_market_heap'] 
    if order['Side'] == "Sell": 
        currObj = sellOrderNode(time_string_to_int(order['Time']), order['OrderID'], order['Instrument'], order['Quantity'], order['Client'], order['Price'], order['Side'], client_data[order['Client']]["Rating"], client_data[order['Client']]["PositionCheck"]) 
        if order['Price'] == "Market": 
            heapq.heappush(instrument_dict[order['Instrument']]['sell_market_heap'],currObj) 
        else: 
            heapq.heappush(instrument_dict[order['Instrument']]['sell_heap'],currObj) 
 
        #sellorder workflow 
             
    else: 
        currObj = buyOrderNode(time_string_to_int(order['Time']), order['OrderID'], order['Instrument'], order['Quantity'], order['Client'], order['Price'], order['Side'], client_data[order['Client']]["Rating"], client_data[order['Client']]["PositionCheck"]) 
         
        if order['Price'] == "Market": 
            heapq.heappush(instrument_dict[order['Instrument']]['buy_market_heap'],currObj) 
        else: 
            heapq.heappush(instrument_dict[order['Instrument']]['buy_heap'],currObj) 
         
        #buyorder workflow


# for order in order_data:

    # if order['Time'] == "09:30:00":
    #     break

    # if order['Side'] == "Sell":
    #     # def __init__(self, time, order_id, instrument, quantity, client_id, price, buy_or_sell, client_rating, client_position_check):
    #     currObj = sellOrderNode(time_string_to_int(order['Time']), order['OrderID'], order['Instrument'], order['Quantity'], order['Client'], order['Price'], order['Side'], client_data[order['Client']]["Rating"], client_data[order['Client']]["PositionCheck"])
        
    #     if client_data[order['Client']]["PositionCheck"] != "Y":
    #         if order['Price'] == "Market":
    #             heapq.heappush(sellHeapMarket, currObj)
    #             # sellHeapMarket.append(currObj)
    #         else:
    #             heapq.heappush(sellHeap, currObj)


    # else:
    #     currObj = buyOrderNode(time_string_to_int(order['Time']), order['OrderID'], order['Instrument'], order['Quantity'], order['Client'], order['Price'], order['Side'], client_data[order['Client']]["Rating"], client_data[order['Client']]["PositionCheck"])
        
    #     if order['Price'] == "Market":
    #         # buyHeapMarket.heappush(currObj)
    #         heapq.heappush(buyHeapMarket, currObj)
    #     else:
    #         # buyHeap.heappush(currObj)
    #         heapq.heappush(buyHeap, currObj)



print (instrument_dict)
# Out:
# {'INST_000': {'buy_heap': [<buyOrderNode.buyOrderNode object at 0x10caaf160>, <buyOrderNode.buyOrderNode object at 0x10cc30580>, <buyOrderNode.buyOrderNode object at 0x10caa7190>, <buyOrderNode.buyOrderNode object at 0x10cb45d60>, <buyOrderNode.buyOrderNode object at 0x10ca4a220>, <buyOrderNode.buyOrderNode object at 0x10c9c01c0>, <buyOrderNode.buyOrderNode object at 0x10cca9580>, <buyOrderNode.buyOrderNode object at 0x10ca3c880>, <buyOrderNode.buyOrderNode object at 0x10cc78670>, <buyOrderNode.buyOrderNode object at 0x10caab850>, <buyOrderNode.buyOrderNode object at 0x10c992610>, <buyOrderNode.buyOrderNode object at 0x10cc34c70>, <buyOrderNode.buyOrderNode object at 0x10cb4bbe0>, <buyOrderNode.buyOrderNode object at 0x10c9e23a0>, <buyOrderNode.buyOrderNode object at 0x10ca70e20>, <buyOrderNode.buyOrderNode object at 0x10c9dae20>, <buyOrderNode.buyOrderNode object at 0x10c969160>, <buyOrderNode.buyOrderNode object at 0x10c93d370>, <buyOrderNode.buyOrderNode object at 0x10c988cd0>, <buyOrderNode.buyOrderNode object at 0x10ca0d6a0>, <buyOrderNode.buyOrderNode object at 0x10c9eb280>, <buyOrderNode.buyOrderNode object at 0x10cb1d220>, <buyOrderNode.buyOrderNode object at 0x10c939760>, <buyOrderNode.buyOrderNode object at 0x10cb3d880>, <buyOrderNode.buyOrderNode object at 0x10cac4ee0>, <buyOrderNode.buyOrderNode object at 0x10c98e4f0>, <buyOrderNode.buyOrderNode object at 0x10ca7e7c0>, <buyOrderNode.buyOrderNode object at 0x10c9b2910>, <buyOrderNode.buyOrderNode object at 0x10cb275b0>, <buyOrderNode.buyOrderNode object at 0x10ca37310>, <buyOrderNode.buyOrderNode object at 0x10c9e20a0>, <buyOrderNode.buyOrderNode object at 0x10ca7e670>, <buyOrderNode.buyOrderNode object at 0x10cabdb50>, <buyOrderNode.buyOrderNode object at 0x10ca12a60>, <buyOrderNode.buyOrderNode object at 0x10ca12d60>, <buyOrderNode.buyOrderNode object at 0x10c977eb0>, <buyOrderNode.buyOrderNode object at 0x10cae72e0>, <buyOrderNode.buyOrderNode object at 0x10c9f67f0>, <buyOrderNode.buyOrderNode object at 0x10c934550>, <buyOrderNode.buyOrderNode object at 0x10ca854f0>, <buyOrderNode.buyOrderNode object at 0x10caccca0>, <buyOrderNode.buyOrderNode object at 0x10cad2dc0>, <buyOrderNode.buyOrderNode object at 0x10c957a00>, <buyOrderNode.buyOrderNode object at 0x10ca938b0>, <buyOrderNode.buyOrderNode object at 0x10cb1ab50>, <buyOrderNode.buyOrderNode object at 0x10ca45d60>, <buyOrderNode.buyOrderNode object at 0x10c9c5f40>, <buyOrderNode.buyOrderNode object at 0x10ca16d90>, <buyOrderNode.buyOrderNode object at 0x10ca8bb20>, <buyOrderNode.buyOrderNode object at 0x10caa7d30>, <buyOrderNode.buyOrderNode object at 0x10cacca60>, <buyOrderNode.buyOrderNode object at 0x10c995dc0>, <buyOrderNode.buyOrderNode object at 0x10c9856d0>, <buyOrderNode.buyOrderNode object at 0x10cb328b0>, <buyOrderNode.buyOrderNode object at 0x10cb32820>, <buyOrderNode.buyOrderNode object at 0x10cb37790>, <buyOrderNode.buyOrderNode object at 0x10c9a4c10>, <buyOrderNode.buyOrderNode object at 0x10cb40610>, <buyOrderNode.buyOrderNode object at 0x10cebf670>, <buyOrderNode.buyOrderNode object at 0x10cad74f0>, <buyOrderNode.buyOrderNode object at 0x10c9e2820>, <buyOrderNode.buyOrderNode object at 0x10ccb2280>, <buyOrderNode.buyOrderNode object at 0x10c91b790>, <buyOrderNode.buyOrderNode object at 0x10cd25ca0>, <buyOrderNode.buyOrderNode object at 0x10c9776a0>, <buyOrderNode.buyOrderNode object at 0x10c9fea30>, <buyOrderNode.buyOrderNode object at 0x10cd356d0>, <buyOrderNode.buyOrderNode object at 0x10ca12d30>, <buyOrderNode.buyOrderNode object at 0x10cd25c40>, <buyOrderNode.buyOrderNode object at 0x10ca329a0>, <buyOrderNode.buyOrderNode object at 0x10cb2b4c0>, <buyOrderNode.buyOrderNode object at 0x10cc78cd0>, <buyOrderNode.buyOrderNode object at 0x10cd9df70>, <buyOrderNode.buyOrderNode object at 0x10c9f63a0>, <buyOrderNode.buyOrderNode object at 0x10cc3dee0>, <buyOrderNode.buyOrderNode object at 0x10ca04610>, <buyOrderNode.buyOrderNode object at 0x10ca81070>, <buyOrderNode.buyOrderNode object at 0x10d6f30 ...

# %%
temp = instrument_dict['INST_000']

# {'buy_heap' :[], 'sell_heap':[], 'sell_market_heap':[], 'buy_market_heap':[]} 

buy_market_qty = 0
sell_market_qty = 0
bestqty = 0
bestprice = 0

curr_sell_price = None

buy_market_len = len(temp["buy_market_heap"])
sell_market_len = len(temp["sell_market_heap"])
buy_market_pointer = 0
sell_market_pointer = 0

while buy_market_pointer < buy_market_len:
    order = heapq.heappop(temp["buy_market_heap"])
    buy_market_qty += float(order.quantity)
    heapq.heappush(temp["buy_market_heap"], order)
    buy_market_pointer+=1

while sell_market_pointer < sell_market_len:
    order = heapq.heappop(temp["sell_market_heap"])
    sell_market_qty += float(order.quantity)
    heapq.heappush(temp["sell_market_heap"], order)
    sell_market_pointer +=1

print(buy_market_qty, sell_market_qty, bestqty)

print(temp["buy_heap"])
# Out:
# 2948000.0 14168000.0 0
rderNode.buyOrderNode object at 0x10cb328b0>, <buyOrderNode.buyOrderNode object at 0x10cb32820>, <buyOrderNode.buyOrderNode object at 0x10cb37790>, <buyOrderNode.buyOrderNode object at 0x10c9a4c10>, <buyOrderNode.buyOrderNode object at 0x10cb40610>, <buyOrderNode.buyOrderNode object at 0x10cebf670>, <buyOrderNode.buyOrderNode object at 0x10cad74f0>, <buyOrderNode.buyOrderNode object at 0x10c9e2820>, <buyOrderNode.buyOrderNode object at 0x10ccb2280>, <buyOrderNode.buyOrderNode object at 0x10c91b790>, <buyOrderNode.buyOrderNode object at 0x10cd25ca0>, <buyOrderNode.buyOrderNode object at 0x10c9776a0>, <buyOrderNode.buyOrderNode object at 0x10c9fea30>, <buyOrderNode.buyOrderNode object at 0x10cd356d0>, <buyOrderNode.buyOrderNode object at 0x10ca12d30>, <buyOrderNode.buyOrderNode object at 0x10cd25c40>, <buyOrderNode.buyOrderNode object at 0x10ca329a0>, <buyOrderNode.buyOrderNode object at 0x10cb2b4c0>, <buyOrderNode.buyOrderNode object at 0x10cc78cd0>, <buyOrderNode.buyOrderNode object at 0x10cd9df70>, <buyOrderNode.buyOrderNode object at 0x10c9f63a0>, <buyOrderNode.buyOrderNode object at 0x10cc3dee0>, <buyOrderNode.buyOrderNode object at 0x10ca04610>, <buyOrderNode.buyOrderNode object at 0x10ca81070>, <buyOrderNode.buyOrderNode object at 0x10d6f3070>, <buyOrderNode.buyOrde ...

# %%
searching_flag = False
popped_sells = []
heapq.heapify(popped_sells)

popped_buys = []
heapq.heapify(popped_buys)

curr_sell_qty = 0
curr_buy_qty = 0

while len(temp["sell_heap"]):
    
    curr_sell_qty = 0
    curr_buy_qty = 0

    # find the first sell limit order price
    if curr_sell_price == None:
        curr_sell_obj = heapq.heappop(temp["sell_heap"])
        # popped_sells.heappush(curr_sell_obj)
        heapq.heappush(popped_sells, curr_sell_obj)
        
        curr_sell_price = float(curr_sell_obj.price)
    
    else:
        searching_flag = True
        # find the next lowest price 
        while searching_flag:
            curr_sell_obj = heapq.heappop(temp["sell_heap"])
            heapq.heappush(popped_sells, curr_sell_obj)
            if float(curr_sell_obj.price) > curr_sell_price:
                curr_sell_price = float(curr_sell_obj.price)
                searching_flag = False


    # search for all sells at this price
    searching_flag = True
    while searching_flag:
        if len(temp["sell_heap"]) ==0:
            break
        curr_sell_obj = heapq.heappop(temp["sell_heap"])
        if float(curr_sell_obj.price) <= curr_sell_price:
            heapq.heappush(popped_sells, curr_sell_obj)
        else:
            searching_flag = False

    # get max sell qty at price 
    idx = 0
    while idx < len(popped_sells):
        currObj = heapq.heappop(popped_sells)
        curr_sell_qty += float(currObj.quantity)

        heapq.heappush(popped_sells, currObj)
        idx+=1
    
    # print(curr_sell_price)

    # get the buy qty eligible at this price
    searching_flag = True
    while searching_flag:
        if len(temp["buy_heap"]) ==0:
            break
        curr_buy_obj = heapq.heappop(temp["buy_heap"])
        # print("curr obj", float(curr_buy_obj.price))

        if float(curr_buy_obj.price) >= curr_sell_price:
            heapq.heappush(popped_buys, curr_buy_obj)
            curr_buy_qty += float(curr_buy_obj.quantity)
            # print(curr_buy_qty)

        
        else:
            searching_flag = False
    
    while len(popped_buys) >0:
        heapq.heappush(temp["buy_heap"], heapq.heappop(popped_buys))

    curr_buy_qty +=buy_market_qty
    curr_sell_qty +=sell_market_qty

    
    if (bestqty < min(curr_buy_qty, curr_sell_qty)):
        bestprice = curr_sell_price
        bestqty = max(bestqty, min(curr_buy_qty, curr_sell_qty))


print(curr_buy_qty, curr_sell_qty)
print(bestqty, bestprice)
print()
# Out:
# 2948000.0 51596000.0
# 14176000.0 99.4

# %%
# node = orderNode(time, order_id, instrument, quantity, client_id, price, buy_or_sell, client_rating, client_position_check)

# loop through order_data and create orderNodes and put it inside a variable called orderBook

client_holdings = {}

instrument_dict= {}

buyHeap = []
sellHeap = []
buyHeapMarket = []
sellHeapMarket = []

heapq.heapify(buyHeap)
heapq.heapify(sellHeap)
heapq.heapify(buyHeapMarket)
heapq.heapify(sellHeapMarket)

for order in order_data: 
     
    if order['Instrument'] not in instrument_dict: 
        instrument_dict[order['Instrument']] = {'buy_heap' :[], 'sell_heap':[], 'sell_market_heap':[], 'buy_market_heap':[]} 
        buy_heap = instrument_dict[order['Instrument']]['buy_heap'] 
        buy_market_heap = instrument_dict[order['Instrument']]['buy_market_heap'] 
        sell_heap = instrument_dict[order['Instrument']]['sell_heap'] 
        sell_market_heap = instrument_dict[order['Instrument']]['sell_market_heap'] 
    if order['Side'] == "Sell": 
        currObj = sellOrderNode(time_string_to_int(order['Time']), order['OrderID'], order['Instrument'], float(order['Quantity']), order['Client'], order['Price'], order['Side'], client_data[order['Client']]["Rating"], client_data[order['Client']]["PositionCheck"]) 
        if order["client_position_check"] == "Y":
            with open('./output_exchange_report.csv', 'a', newline="") as csvfile: 
                    # creating a csv writer object 
                    csvwriter = csv.writer(csvfile) 
                    myrows = [[currObj.order_id, 'REJECTED-POSITION CHECK FAILED']] 
                    csvwriter.writerows(myrows)
            continue
        if order['Price'] == "Market": 
            heapq.heappush(instrument_dict[order['Instrument']]['sell_market_heap'],currObj) 
        else: 
            heapq.heappush(instrument_dict[order['Instrument']]['sell_heap'],currObj) 
 
        #sellorder workflow 
             
    else: 
        currObj = buyOrderNode(time_string_to_int(order['Time']), order['OrderID'], order['Instrument'], float(order['Quantity']), order['Client'], order['Price'], order['Side'], client_data[order['Client']]["Rating"], client_data[order['Client']]["PositionCheck"]) 
         
        if order['Price'] == "Market": 
            heapq.heappush(instrument_dict[order['Instrument']]['buy_market_heap'],currObj) 
        else: 
            heapq.heappush(instrument_dict[order['Instrument']]['buy_heap'],currObj) 
         

for key in instrument_dict.keys():

    temp = instrument_dict[key]

    # {'buy_heap' :[], 'sell_heap':[], 'sell_market_heap':[], 'buy_market_heap':[]} 

    buy_market_qty = 0
    sell_market_qty = 0
    
    bestqty = 0
    buyerMore = None
    bestprice = 0

    bestqtysell=0
    bestqtybuy=0

    bestpoppedbuy = None
    bestpoppedsell = None


    curr_sell_price = None

    buy_market_len = len(temp["buy_market_heap"])
    sell_market_len = len(temp["sell_market_heap"])
    buy_market_pointer = 0
    sell_market_pointer = 0

    while buy_market_pointer < buy_market_len:
        order = heapq.heappop(temp["buy_market_heap"])
        buy_market_qty += float(order.quantity)
        heapq.heappush(temp["buy_market_heap"], order)
        buy_market_pointer+=1

    while sell_market_pointer < sell_market_len:
        order = heapq.heappop(temp["sell_market_heap"])
        sell_market_qty += float(order.quantity)
        heapq.heappush(temp["sell_market_heap"], order)
        sell_market_pointer +=1

    # print(buy_market_qty, sell_market_qty, bestqty)

    # print(temp["buy_heap"])

    searching_flag = False
    popped_sells = []
    heapq.heapify(popped_sells)

    popped_buys = []
    heapq.heapify(popped_buys)

    curr_sell_qty = 0
    curr_buy_qty = 0

    while len(temp["sell_heap"]):
        
        curr_sell_qty = 0
        curr_buy_qty = 0

        # find the first sell limit order price
        if curr_sell_price == None:
            curr_sell_obj = heapq.heappop(temp["sell_heap"])
            # popped_sells.heappush(curr_sell_obj)
            heapq.heappush(popped_sells, curr_sell_obj)
            
            curr_sell_price = float(curr_sell_obj.price)
        
        else:
            searching_flag = True
            # find the next lowest price 
            while searching_flag:
                curr_sell_obj = heapq.heappop(temp["sell_heap"])
                heapq.heappush(popped_sells, curr_sell_obj)
                if float(curr_sell_obj.price) > curr_sell_price:
                    curr_sell_price = float(curr_sell_obj.price)
                    searching_flag = False


        # search for all sells at this price
        searching_flag = True
        while searching_flag:
            if len(temp["sell_heap"]) ==0:
                break
            curr_sell_obj = heapq.heappop(temp["sell_heap"])
            if float(curr_sell_obj.price) <= curr_sell_price:
                heapq.heappush(popped_sells, curr_sell_obj)
            else:
                searching_flag = False

        # get max sell qty at price 
        idx = 0
        while idx < len(popped_sells):
            currObj = heapq.heappop(popped_sells)
            curr_sell_qty += float(currObj.quantity)

            heapq.heappush(popped_sells, currObj)
            idx+=1
        
        # print(curr_sell_price)

        # get the buy qty eligible at this price
        searching_flag = True
        while searching_flag:
            if len(temp["buy_heap"]) ==0:
                break
            curr_buy_obj = heapq.heappop(temp["buy_heap"])
            # print("curr obj", float(curr_buy_obj.price))

            if float(curr_buy_obj.price) >= curr_sell_price:
                heapq.heappush(popped_buys, curr_buy_obj)
                curr_buy_qty += float(curr_buy_obj.quantity)
                # print(curr_buy_qty)

            
            else:
                searching_flag = False
        
        while len(popped_buys) >0:
            heapq.heappush(temp["buy_heap"], heapq.heappop(popped_buys))

        curr_buy_qty +=buy_market_qty
        curr_sell_qty +=sell_market_qty

        
        if (bestqty < min(curr_buy_qty, curr_sell_qty)):
            bestprice = curr_sell_price
            bestqty = max(bestqty, min(curr_buy_qty, curr_sell_qty))
            bestqtybuy = curr_buy_qty
            bestqtysell = curr_sell_qty

            bestpoppedbuy = popped_buys
            bestpoppedsell = popped_sells

            if bestqtysell > bestqtybuy:
                buyerMore = False
            else:
                buyerMore = True


    print(key)
    print("best qty: ", bestqty)
    print("best price: ", bestprice)
    print("best buy qty: ", bestqtybuy)
    print("best sell qty: ", bestqtysell)

    totalqty = float(bestqty)


    while totalqty > 0 and len(temp["buy_market_heap"])>0 :
        node = heapq.heappop(temp["buy_market_heap"])
        float(node.quantity)
        node_qty = float(node.quantity)
        
        qty_traded = min(node_qty, totalqty)
        totalqty -= qty_traded

        node.quantity -= float(qty_traded)
        bestqtybuy -= float(qty_traded)

        if node.client_id not in client_holdings.keys():
            client_holdings[node.client_id] = {}
        
        if node.instrument not in client_holdings[node.client_id].keys():
            client_holdings[node.client_id][node.instrument] = 0
        
        client_holdings[node.client_id][node.instrument] += float(qty_traded)
        
        if node.quantity > 0:
            heapq.heappush(temp["buy_market_heap"], node)
            break
    
    totalqty = float(bestqty)

    while totalqty > 0 and len(temp["sell_market_heap"])>0:
        node = heapq.heappop(temp["sell_market_heap"])
        node_qty = float(node.quantity)
        
        qty_traded = min(float(node.quantity), totalqty)
        totalqty -= qty_traded

        node.quantity -= float(qty_traded)
        bestqtysell -= float(qty_traded)

        if node.client_id not in client_holdings.keys():
            client_holdings[node.client_id] = {}
        
        if node.instrument not in client_holdings[node.client_id].keys():
            client_holdings[node.client_id][node.instrument] = 0
        
        client_holdings[node.client_id][node.instrument] -= float(qty_traded)
        
        if node.quantity > 0:
            heapq.heappush(temp["sell_market_heap"], node)
            break

    if bestqtysell == 0.0 or bestqtybuy== 0.0:
        print ("Done")
    
    else:
        total_remaining = min (bestqtysell, bestqtybuy)

        totalqty = float(total_remaining)

        while totalqty > 0 and len(bestpoppedbuy)>0:
            node = heapq.heappop(bestpoppedbuy)
            float(node.quantity)
            node_qty = float(node.quantity)
            
            qty_traded = min(node_qty, totalqty)
            totalqty -= qty_traded

            node.quantity -= float(qty_traded)
            bestqtybuy -= float(qty_traded)

            if node.client_id not in client_holdings.keys():
                client_holdings[node.client_id] = {}
            
            if node.instrument not in client_holdings[node.client_id].keys():
                client_holdings[node.client_id][node.instrument] = 0
            
            client_holdings[node.client_id][node.instrument] += float(qty_traded)
            
            if node.quantity > 0:
                heapq.heappush(bestpoppedbuy, node)
                break
        
        totalqty = float(total_remaining)

        # while totalqty > 0 and len(temp["sell_heap"])>0:
        while totalqty > 0 and len(bestpoppedsell)>0:
            node = heapq.heappop(bestpoppedsell)
            node_qty = float(node.quantity)
            
            qty_traded = min(float(node.quantity), totalqty)
            totalqty -= qty_traded

            node.quantity -= float(qty_traded)
            bestqtysell -= float(qty_traded)

            if node.client_id not in client_holdings.keys():
                client_holdings[node.client_id] = {}
            
            if node.instrument not in client_holdings[node.client_id].keys():
                client_holdings[node.client_id][node.instrument] = 0
            
            client_holdings[node.client_id][node.instrument] -= float(qty_traded)
            
            if node.quantity > 0:
                heapq.heappush(bestpoppedsell, node)
                break
        

        while len(bestpoppedsell)>0:
            curr = heapq.heappop(bestpoppedsell)
            heapq.heappush(temp["sell_heap"], curr)
        while len(bestpoppedbuy)>0:
            curr = heapq.heappop(bestpoppedsell)
            heapq.heappush(temp["buy_heap"],curr)
        

    


        

    
    

    # if buyerMore:

        # while len(temp["buy_market_heap"]) >0:
            # current_market_buy = heapq.heappop(temp["buy_market_heap"])
            # bestqtybuy -= float(current_market_buy.quantity)

            # if current_market_buy.client_id not in client_holdings.keys():
            #     client_holdings[current_market_buy.client_id] = {}
            
            # if current_market_buy.instrument not in client_holdings[current_market_buy.client_id].keys():
            #     client_holdings[current_market_buy.client_id][current_market_buy.instrument] = 0
            
            # client_holdings[current_market_buy.client_id][current_market_buy.instrument] += float(current_market_buy.quantity)

        


        
        # while len(temp["sell_market_heap"]) >0:
        #     current_market_sell = heapq.heappop(temp["sell_market_heap"])
        #     bestqtysell -= float(current_market_sell.quantity)

        #     if current_market_sell.client_id not in client_holdings.keys():
        #         client_holdings[current_market_sell.client_id] = {}
            
        #     if current_market_sell.instrument not in client_holdings[current_market_sell.client_id].keys():
        #         client_holdings[current_market_sell.client_id][current_market_sell.instrument] = 0
            
        #     client_holdings[current_market_sell.client_id][current_market_sell.instrument] += float(current_market_sell.quantity)




    print("remaining buy qty: ", bestqtybuy)
    print("remaining sell qty: ", bestqtysell)

    # print(len(temp["sell_heap"]))
    # print(len(temp["buy_heap"]))

    print(client_holdings)
    print()
# Out:
# INST_000
# best qty:  14176000.0
# best price:  99.4
# best buy qty:  24606500.0
# best sell qty:  14176000.0
# remaining buy qty:  22315500.0
# remaining sell qty:  0.0
# {'CLIENT_104': {'INST_000': 2270500.0}, 'CLIENT_103': {'INST_000': 1442500.0}, 'CLIENT_107': {'INST_000': 319500.0}, 'CLIENT_111': {'INST_000': 1011000.0}, 'CLIENT_110': {'INST_000': 968500.0}, 'CLIENT_108': {'INST_000': 1234500.0}, 'CLIENT_106': {'INST_000': 378500.0}, 'CLIENT_113': {'INST_000': 1829500.0}, 'CLIENT_112': {'INST_000': 566500.0}, 'CLIENT_102': {'INST_000': 1238500.0}, 'CLIENT_105': {'INST_000': 1153500.0}, 'CLIENT_114': {'INST_000': 49000.0}, 'CLIENT_101': {'INST_000': 726000.0}, 'CLIENT_100': {'INST_000': 2134500.0}, 'CLIENT_109': {'INST_000': 1144500.0}}
#
# INST_001
# best qty:  692900.0
# best price:  100.8
# best buy qty:  926950.0
# best sell qty:  692900.0
# remaining buy qty:  670350.0
# remaining sell qty:  0.0
# {'CLIENT_104': {'INST_000': 2270500.0, 'INST_001': 40800.0}, 'CLIENT_103': {'INST_000': 1442500.0, 'INST_001': 167200.0}, 'CLIENT_107': {'INST_000': 319500.0, 'INST_001': 10000.0}, 'CLIENT_111': {'INST_000': 1011000.0, 'INST_001': 74950.0}, 'CLIENT_110': {'INST_000': 968500.0, 'INST_001': 8450.0}, 'CLIENT_108': {'INST_000': 1234500.0, 'INST_001': 144300.0}, 'CLIENT_106': {'INST_000': 378500.0, 'INST_001':